# %% [markdown]
# ## Ejercicio 7
# 1) Mostrar que $\theta_1$ es un estimador insesgado, que $E(\theta_1)=pc(b-a)=I$
#
# 2) Mostrar que $V(\theta_1)=\frac{I}{N}[c(b-a)-I]$

# %%
#importamos el módulo que vamos a usar 
import random
import matplotlib.pyplot as plt   
import numpy as np
import pandas as pd

# %%
def test_function(x):
    return(np.sqrt(np.arctan(x)))

def integrate(x1,x2,func=test_function,n=100000):
    X=np.linspace(x1,x2,1000)
    y1=0
    y2=max((func(X)))
    cc=y2
    area=(x2-x1)*(y2-y1)
    check=[]
    xs=[]
    ys=[]
    sum=0
    for i in range(n):
        x=np.random.uniform(x1,x2)
        xs.append(x)
        y=np.random.uniform(y1,y2)
        ys.append(y)
        if abs(y)>abs(func(x)) or y<0:
            check.append(0)
        else:
            check.append(1)
            sum=sum+1
    p=sum/n
    return(cc,p,np.mean(check)*area,xs,ys,check)
cc,p,I,x,y,c=integrate(0,1)

_,_,_,x,y,c=integrate(0,1,n=500)
df=pd.DataFrame()
df['x']=x
df['y']=y
df['c']=c
b=1
a=0
print("Evaluación de la integral I =",I)
E=(p*cc)*(b-a)
V=(I/100000)*(cc*(b-a)-I)
print("Evaluación de E(theta) =",E)
print("a) ",E, "=", I, "=> [E(theta) = I]")
print("b)  V =",V)
# Out:
# Evaluación de la integral I = 0.6284323751078053
# Evaluación de E(theta) = 0.6284323751078053
# a)  0.6284323751078053 = 0.6284323751078053 => [E(theta) = I]
# b)  V = 1.620064415631273e-06
